# %%
from tools import *

rho = rdm_ginibre(8)
psi, u = get_abs_lambda(rho)
qc = get_psi_circuit(psi, rho)
qc.draw(output='mpl')
# Out:
# 3.0
# [0.02902488 0.06933493 0.14085056 0.2186252  0.28659969 0.3266602
#  0.52852798 0.67714568]
# 0.029024883272059786
# 0.06933492733068211
# 0.14085055575304578
# 0.21862519718756984
# 0.2865996943529478
# 0.32666020372125903
# 0.5285279818390021
# 0.6771456763626426
# lista [Qubit(QuantumRegister(3, 'q3'), 0), Qubit(QuantumRegister(3, 'q3'), 1), Qubit(QuantumRegister(3, 'q3'), 2)]
# 3
# QuantumRegister(3, 'q3')
